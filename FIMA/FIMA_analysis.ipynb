# %% [markdown]
# # FEMA

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import geopandas as gpd

# %%
df1 = pd.read_csv("FimaNfipClaimsV1_1.csv", index_col = 0)
df2 = pd.read_csv("FimaNfipClaimsV1_2.csv", index_col = 0)
df3 = pd.read_csv("FimaNfipClaimsV1_3.csv", index_col = 0)
df = pd.concat([df1, df2, df3], ignore_index = True)

df
# Out:
#          agricultureStructureIndicator                  asOfDate  \
# 0                                  0.0  2021-07-24T00:00:00.000Z
# 1                                  0.0  2021-07-24T00:00:00.000Z
# 2                                  0.0  2021-11-20T00:00:00.000Z
# 3                                  0.0  2021-11-20T00:00:00.000Z
# 4                                  0.0  2021-11-20T00:00:00.000Z
# ...                                ...                       ...
# 2570084                            0.0  2022-04-06T00:00:00.000Z
# 2570085                            0.0  2022-04-02T00:00:00.000Z
# 2570086                            0.0  2022-04-02T00:00:00.000Z
# 2570087                            0.0  2022-04-02T00:00:00.000Z
# 2570088                            0.0  2022-04-09T00:00:00.000Z
#
#          baseFloodElevation  basementEnclosureCrawlspace  \
# 0                       NaN                          1.0
# 1                       NaN                          NaN
# ...

# %%
geo_df = gpd.GeoDataFrame(df)

geo_df
# Out:
#          agricultureStructureIndicator                  asOfDate  \
# 0                                  0.0  2021-07-24T00:00:00.000Z
# 1                                  0.0  2021-07-24T00:00:00.000Z
# 2                                  0.0  2021-11-20T00:00:00.000Z
# 3                                  0.0  2021-11-20T00:00:00.000Z
# 4                                  0.0  2021-11-20T00:00:00.000Z
# ...                                ...                       ...
# 2570084                            0.0  2022-04-06T00:00:00.000Z
# 2570085                            0.0  2022-04-02T00:00:00.000Z
# 2570086                            0.0  2022-04-02T00:00:00.000Z
# 2570087                            0.0  2022-04-02T00:00:00.000Z
# 2570088                            0.0  2022-04-09T00:00:00.000Z
#
#          baseFloodElevation  basementEnclosureCrawlspace  \
# 0                       NaN                          1.0
# 1                       NaN                          NaN
# ...

# %%
geo_df.isna().sum()
# Out:
# agricultureStructureIndicator                      55
# asOfDate                                            0
# baseFloodElevation                            1959704
# basementEnclosureCrawlspace                   1797897
# reportedCity                                        0
# condominiumIndicator                            41590
# policyCount                                        55
# countyCode                                      43815
# communityRatingSystemDiscount                  936113
# dateOfLoss                                          0
# elevatedBuildingIndicator                          55
# elevationCertificateIndicator                 2570089
# elevationDifference                           1886110
# censusTract                                    138042
# floodZone                                      143408
# houseWorship                                       55
# latitude                                        39991
# ...

# %%
geo_df = df.fillna(0)

# %%
geo_df.columns
# Out:
# Index(['agricultureStructureIndicator', 'asOfDate', 'baseFloodElevation',
#        'basementEnclosureCrawlspace', 'reportedCity', 'condominiumIndicator',
#        'policyCount', 'countyCode', 'communityRatingSystemDiscount',
#        'dateOfLoss', 'elevatedBuildingIndicator',
#        'elevationCertificateIndicator', 'elevationDifference', 'censusTract',
#        'floodZone', 'houseWorship', 'latitude', 'locationOfContents',
#        'longitude', 'lowestAdjacentGrade', 'lowestFloorElevation',
#        'numberOfFloorsInTheInsuredBuilding', 'nonProfitIndicator',
#        'obstructionType', 'occupancyType', 'originalConstructionDate',
#        'originalNBDate', 'amountPaidOnBuildingClaim',
#        'amountPaidOnContentsClaim',
#        'amountPaidOnIncreasedCostOfComplianceClaim',
#        'postFIRMConstructionIndicator', 'rateMethod',
#        'smallBusinessIndicatorBuilding', 'state',
#        'totalBuildingInsuranceCoverage', 'totalContentsInsuranceCoverage',
# ...

# %%
geo_df.describe()
# Out:
#        agricultureStructureIndicator  baseFloodElevation  \
# count                   2.570089e+06        2.570089e+06
# mean                    1.459093e-04        2.960675e+01
# std                     1.207842e-02        3.641104e+02
# min                     0.000000e+00       -9.998000e+03
# 25%                     0.000000e+00        0.000000e+00
# 50%                     0.000000e+00        0.000000e+00
# 75%                     0.000000e+00        0.000000e+00
# max                     1.000000e+00        9.998000e+03
#
#        basementEnclosureCrawlspace   policyCount    countyCode  \
# count                 2.570089e+06  2.570089e+06  2.570089e+06
# mean                  3.837610e-01  1.263479e+00  2.961581e+04
# std                   8.230084e-01  6.452993e+00  1.495098e+04
# min                   0.000000e+00  0.000000e+00  0.000000e+00
# 25%                   0.000000e+00  1.000000e+00  2.111100e+04
# 50%                   0.000000e+00  1.000000e+00  2.815100e+04
# ...

# %%
geo_df["state"].set_geometry
states = geo_df['state']
us_boundary_map = geo_df.boundary.plot(figsize=(18, 12), color='Black', linewidth=.5)
states.plot(ax=us_boundary_map,  color="MistyRose")
# final_map = northeast.plot(ax=us_boundary_map, color="LightPink")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/sq/p495tjk900x4_c97r6cbwj9m0000gn/T/ipykernel_3576/473916816.py in ?()
# ----> 1 geo_df["state"].set_geometry
#       2 states = geo_df['state']
#       3 us_boundary_map = geo_df.boundary.plot(figsize=(18, 12), color='Black', linewidth=.5)
#       4 states.plot(ax=us_boundary_map,  color="MistyRose")
#
# ~/opt/anaconda3/envs/analysis/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'set_geometry'
